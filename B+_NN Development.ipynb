# %% [markdown]
# # Crowd prediction based on trip chaining results enhanced for providing the results for the quantitative analysis of the mobility model card.

# %% [markdown]
# Predicts #Entries & #Exits per zone, day of the week and timewindow

# %%
# !pip install tensorflow
# Out:
# Requirement already satisfied: tensorflow in c:\users\asimina\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (2.19.0)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\asimina\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from tensorflow) (2.3.1)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\asimina\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in c:\users\asimina\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from tensorflow) (25.2.10)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\users\asimina\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\asimina\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\asimina\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\asimina\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: packaging in c:\users\asimina\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from tensorflow) (24.2)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in c:\users\asimina\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from tensorflow) (5.29.5)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\asimina\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from tensorflow) (2.32.3)
# Requirement already satisfied: setuptools in c:\program files\windowsapps\pythonsoftwarefoundation.python.3.11_3.11.2544.0_x64__qbz5n2kfra8p0\lib\site-packages (from tensorflow) (65.5.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\asimina\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\asimina\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from tensorflow) (3.1.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\asimina\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from tensorflow) (4.12.2)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\asimina\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from tensorflow) (1.17.2)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\asimina\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from tensorflow) (1.73.1)
# Requirement already satisfied: tensorboard~=2.19.0 in c:\users\asimina\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from tensorflow) (2.19.0)
# Requirement already satisfied: keras>=3.5.0 in c:\users\asimina\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from tensorflow) (3.10.0)
# Requirement already satisfied: numpy<2.2.0,>=1.26.0 in c:\users\asimina\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from tensorflow) (2.1.3)
# Requirement already satisfied: h5py>=3.11.0 in c:\users\asimina\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from tensorflow) (3.14.0)
# Requirement already satisfied: ml-dtypes<1.0.0,>=0.5.1 in c:\users\asimina\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from tensorflow) (0.5.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\asimina\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from tensorflow) (0.31.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\asimina\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from astunparse>=1.6.0->tensorflow) (0.45.1)
# Requirement already satisfied: rich in c:\users\asimina\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from keras>=3.5.0->tensorflow) (14.0.0)
# Requirement already satisfied: namex in c:\users\asimina\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from keras>=3.5.0->tensorflow) (0.1.0)
# Requirement already satisfied: optree in c:\users\asimina\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from keras>=3.5.0->tensorflow) (0.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\asimina\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from requests<3,>=2.21.0->tensorflow) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\asimina\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from requests<3,>=2.21.0->tensorflow) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\asimina\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from requests<3,>=2.21.0->tensorflow) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\asimina\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from requests<3,>=2.21.0->tensorflow) (2025.1.31)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\asimina\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from tensorboard~=2.19.0->tensorflow) (3.8.2)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\asimina\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from tensorboard~=2.19.0->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\asimina\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from tensorboard~=2.19.0->tensorflow) (3.1.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\asimina\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from werkzeug>=1.0.1->tensorboard~=2.19.0->tensorflow) (3.0.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\asimina\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from rich->keras>=3.5.0->tensorflow) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\asimina\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from rich->keras>=3.5.0->tensorflow) (2.19.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\asimina\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.5.0->tensorflow) (0.1.2)
# [notice] A new release of pip is available: 24.0 -> 25.2
# [notice] To update, run: C:\Users\Asimina\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %% [markdown]
# ### Imports

# %%
import datetime;from datetime import timedelta;import pandas as pd;import math;import numpy as np;
import matplotlib.pyplot as plt;import math; from math import radians, sin, cos, sqrt, atan2;import time; 
from sklearn.preprocessing import MinMaxScaler;from sklearn.model_selection import train_test_split; 
import tensorflow as tf
from tensorflow.keras.models import Sequential;from tensorflow.keras.layers import Dense, Activation, Flatten;from tensorflow.keras import optimizers;
from sklearn import datasets, linear_model;from sklearn.model_selection import cross_val_score, KFold;
from sklearn.metrics import mean_squared_error, r2_score, accuracy_score; import tensorflow as tf
from tensorflow import keras; from tensorflow.keras import layers;from tensorflow.keras.callbacks import ReduceLROnPlateau;import joblib

# %% [markdown]
# ###  NN development

# %%
df6 = pd.read_csv("Data/A_df.csv", sep=",", encoding='utf-8')
df6.tail(2)
# Out:
#        Unnamed: 0 EntryStop_Zone  datetime_day_week  datetime_W  m_entries  \
# 52899       52899      Šķirotava                  7          79   5.111111
# 52900       52900      Šķirotava                  7          80   3.000000
#
#         m_exits
# 52899  4.555556
# 52900  2.500000

# %%
new_order = ['datetime_day_week', 'datetime_W','EntryStop_Zone', 'm_entries','m_exits']
df6 = df6[new_order]

# %%
# Define feature columns
num_cols = ['datetime_day_week', 'datetime_W']  # First two columns numerical features to be scaled
em_col = ['zone_codes']  #column for embedding
target_col = ['m_entries', 'm_exits']       ### NEW: list of two targets

# %%
df6['EntryStop_Zone'].nunique()
# Out:
# 133

# %%
# Normalize time features (Min-Max Scaling)
scaler = MinMaxScaler()
df6[num_cols] = scaler.fit_transform(df6[num_cols])

# %%
df6.head(2)
# Out:
#    datetime_day_week  datetime_W EntryStop_Zone  m_entries   m_exits
# 0                0.0    0.152941       Acone #1   2.500000  2.500000
# 1                0.0    0.188235       Acone #1   2.444444  2.444444

# %%
df6.shape
# Out:
# (52901, 5)

# %%
#string to integer
df6["EntryStop_Zone"] = df6["EntryStop_Zone"].astype("category")
df6["zone_codes"] = df6["EntryStop_Zone"].cat.codes

# %%
zone_categories = df6["EntryStop_Zone"].cat.categories  # returns an Index of category labels

# %%
forward_zone_map = {zone_label: i for i, zone_label in enumerate(zone_categories)}
reverse_zone_map = {i: zone_label for i, zone_label in enumerate(zone_categories)}
joblib.dump(forward_zone_map, 'forward_zone_map.joblib')
joblib.dump(reverse_zone_map, 'reverse_zone_map.joblib')
# Out:
# ['reverse_zone_map.joblib']

# %%
print(df6.dtypes)
# Out:
# datetime_day_week     float64
# datetime_W            float64
# EntryStop_Zone       category
# m_entries             float64
# m_exits               float64
# zone_codes              int16
# dtype: object

# %%
df6.tail(2)
# Out:
#        datetime_day_week  datetime_W EntryStop_Zone  m_entries   m_exits  \
# 52899                1.0    0.823529      Šķirotava   5.111111  4.555556
# 52900                1.0    0.835294      Šķirotava   3.000000  2.500000
#
#        zone_codes
# 52899         132
# 52900         132

# %%
X_train, X_test, y_train_raw, y_test_raw = train_test_split(
    df6[num_cols + em_col], df6[target_col], test_size=0.2, random_state=42
)

# %%
# Convert DataFrame to NumPy arrays
X_train_num = np.array(X_train[num_cols])  # Time features remain 2D
X_train_em = np.array(X_train[em_col]).reshape(-1, 1)  # Reshape stop_id for embedding

X_test_num = np.array(X_test[num_cols])
X_test_em = np.array(X_test[em_col]).reshape(-1, 1)

y_train_raw = np.asarray(y_train_raw).astype("float32")  # shape (n, 2)
y_test_raw  = np.asarray(y_test_raw).astype("float32")

# %%
y_train = y_train_raw.astype("float32")
y_test  = y_test_raw.astype("float32")

# %%
###################################################################

# %%
# Weight for large value predictions

# %%
# Row-level weight = sqrt(max(entries, exits))      (sqrt tames outliers a bit)
row_weight = np.sqrt(np.max(y_train_raw, axis=1))
row_weight = (row_weight / row_weight.mean()).astype("float32")
print(f"Mean sample-weight = {row_weight.mean():.2f}")
# Out:
# Mean sample-weight = 1.00

# %%
#Log for small values predictions:
#Instead of using   y_train = np.log1p(y_train_raw) & y_test  = np.log1p(y_test_raw), include the log in the loss:  loss=keras.losses.MeanSquaredLogarithmicError()

# %%
##################################################################

# %%
# Define input layers
num_input = keras.Input(shape=(2,), name="num_input")  # First two columns (num scaled features)
em_input = keras.Input(shape=(1,), name="em_input")  # Fourth column (categorical zone for embedding)

# Embedding layer for zone (assuming max 133 unique zones)
embedding_dim = 48  # Tuneable hyperparameter
zone_embedding = layers.Embedding(input_dim=133, output_dim=embedding_dim)(em_input)
zone_embedding = layers.Flatten()(zone_embedding)  # Flatten the embeddings

# Concatenate stop embeddings with time features
merged = layers.Concatenate()([num_input, zone_embedding])

# Fully connected layers
x = layers.Dense(128, activation="relu")(merged)   # wider
x = layers.BatchNormalization()(x)
x = layers.Dropout(0.15)(x)
x = layers.Dense(64, activation="relu")(x)
x = layers.BatchNormalization()(x)
x = layers.Dropout(0.15)(x)
x = layers.Dense(32, activation="relu")(x)
x = layers.Dense(16, activation="relu")(x)
output = layers.Dense(2, activation="linear")(x)

# Define the model
model = keras.Model(inputs=[num_input, em_input], outputs=output)

model.compile(
    optimizer=keras.optimizers.Adam(learning_rate=0.005),
    loss=keras.losses.MeanSquaredLogarithmicError(),
    metrics=[keras.metrics.MeanAbsoluteError(name="mae")]
)


# Learning rate scheduler to reduce learning rate when validation loss stops improving
lr_scheduler = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=5, min_lr=1e-6)

# Summary of the model
model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ em_input            │ (None, 1)         │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ embedding           │ (None, 1, 48)     │      6,384 │ em_input[0][0]    │
# │ (Embedding)         │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ num_input           │ (None, 2)         │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ flatten (Flatten)   │ (None, 48)        │          0 │ embedding[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate         │ (None, 50)        │          0 │ num_input[0][0],  │
# │ (Concatenate)       │                   │            │ flatten[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 128)       │      6,528 │ concatenate[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalization │ (None, 128)       │        512 │ dense[0][0]       │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout (Dropout)   │ (None, 128)       │          0 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_1 (Dense)     │ (None, 64)        │      8,256 │ dropout[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64)        │        256 │ dense_1[0][0]     │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_1 (Dropout) │ (None, 64)        │          0 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_2 (Dense)     │ (None, 32)        │      2,080 │ dropout_1[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_3 (Dense)     │ (None, 16)        │        528 │ dense_2[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_4 (Dense)     │ (None, 2)         │         34 │ dense_3[0][0]     │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 24,578 (96.01 KB)
#  Trainable params: 24,194 (94.51 KB)
#  Non-trainable params: 384 (1.50 KB)

# %%
# Train the model and store history

history = model.fit(
    [X_train_num, X_train_em], y_train, sample_weight=row_weight,         
    validation_data=([X_test_num, X_test_em], y_test),
    epochs=200, batch_size=128,  callbacks=[lr_scheduler], verbose=1
)


# Plot loss per epoch
plt.figure(figsize=(8, 5))
plt.plot(history.history['loss'], label='Training Loss', marker='o')
plt.plot(history.history['val_loss'], label='Validation Loss', marker='o')
plt.xlabel('Epoch')
plt.ylabel('Loss (MΑE)')
plt.title('Training & Validation Loss per Epoch')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Epoch 1/200
# 331/331 ━━━━━━━━━━━━━━━━━━━━ 8s 11ms/step - loss: 2.0149 - mae: 14.9421 - val_loss: 0.7657 - val_mae: 14.5692 - learning_rate: 0.0050
# Epoch 2/200
# 331/331 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - loss: 0.2433 - mae: 8.7566 - val_loss: 0.3192 - val_mae: 7.7042 - learning_rate: 0.0050
# Epoch 3/200
# 331/331 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 0.2160 - mae: 8.3122 - val_loss: 0.2983 - val_mae: 7.1439 - learning_rate: 0.0050
# Epoch 4/200
# 331/331 ━━━━━━━━━━━━━━━━━━━━ 5s 14ms/step - loss: 0.2011 - mae: 7.8103 - val_loss: 0.2472 - val_mae: 6.9146 - learning_rate: 0.0050
# Epoch 5/200
# 331/331 ━━━━━━━━━━━━━━━━━━━━ 5s 14ms/step - loss: 0.1968 - mae: 7.8043 - val_loss: 0.2628 - val_mae: 7.1474 - learning_rate: 0.0050
# Epoch 6/200
# 331/331 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - loss: 0.2060 - mae: 8.0685 - val_loss: 0.2534 - val_mae: 6.5872 - learning_rate: 0.0050
# Epoch 7/200
# 331/331 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.1924 - mae: 7.5969 - val_loss: 0.2452 - val_mae: 6.8211 - learning_rate: 0.0050
# Epoch 8/200
# 331/331 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 0.1863 - mae: 7.4537 - val_loss: 0.2610 - val_mae: 7.0165 - learning_rate: 0.0050
# Epoch 9/200
# 331/331 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 0.1833 - mae: 7.4054 - val_loss: 0.2434 - val_mae: 6.4472 - learning_rate: 0.0050
# Epoch 10/200
# 331/331 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 0.1805 - mae: 7.3209 - val_loss: 0.2620 - val_mae: 6.5652 - learning_rate: 0.0050
# Epoch 11/200
# 331/331 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 0.1867 - mae: 7.4235 - val_loss: 0.2674 - val_mae: 7.4010 - learning_rate: 0.0050
# Epoch 12/200
# 331/331 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 0.1798 - mae: 7.3208 - val_loss: 0.3044 - val_mae: 8.0460 - learning_rate: 0.0050
# Epoch 13/200
# 331/331 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 0.1748 - mae: 7.1739 - val_loss: 0.2389 - val_mae: 6.3391 - learning_rate: 0.0050
# Epoch 14/200
# 331/331 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 0.1732 - mae: 7.0220 - val_loss: 1.4015 - val_mae: 21.9607 - learning_rate: 0.0050
# Epoch 15/200
# 331/331 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 0.1705 - mae: 6.9769 - val_loss: 0.2198 - val_mae: 6.2038 - learning_rate: 0.0050
# Epoch 16/200
# 331/331 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - loss: 0.1675 - mae: 6.8210 - val_loss: 0.2892 - val_mae: 8.4464 - learning_rate: 0.0050
# Epoch 17/200
# 331/331 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 0.1775 - mae: 7.0618 - val_loss: 0.2282 - val_mae: 6.2205 - learning_rate: 0.0050
# Epoch 18/200
# 331/331 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 0.1680 - mae: 6.8892 - val_loss: 0.2242 - val_mae: 6.1279 - learning_rate: 0.0050
# Epoch 19/200
# 331/331 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 0.1679 - mae: 6.8680 - val_loss: 0.2365 - val_mae: 6.1311 - learning_rate: 0.0050
# Epoch 20/200
# 331/331 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 0.1649 - mae: 6.7257 - val_loss: 0.2462 - val_mae: 6.2603 - learning_rate: 0.0050
# Epoch 21/200
# 331/331 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 0.1572 - mae: 6.5760 - val_loss: 0.2191 - val_mae: 5.7775 - learning_rate: 0.0025
# Epoch 22/200
# 331/331 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 0.1516 - mae: 6.3874 - val_loss: 0.2168 - val_mae: 5.6900 - learning_rate: 0.0025
# Epoch 23/200
# 331/331 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - loss: 0.1438 - mae: 6.2002 - val_loss: 0.2203 - val_mae: 5.7563 - learning_rate: 0.0025
# Epoch 24/200
# 331/331 ━━━━━━━━━━━━━━━━━━━━ 6s 18ms/step - loss: 0.1470 - mae: 6.2301 - val_loss: 0.2072 - val_mae: 5.7580 - learning_rate: 0.0025
# Epoch 25/200
# 331/331 ━━━━━━━━━━━━━━━━━━━━ 5s 14ms/step - loss: 0.1488 - mae: 6.3181 - val_loss: 0.2098 - val_mae: 5.7364 - learning_rate: 0.0025
# Epoch 26/200
# 331/331 ━━━━━━━━━━━━━━━━━━━━ 6s 19ms/step - loss: 0.1447 - mae: 6.2354 - val_loss: 0.2099 - val_mae: 5.7600 - learning_rate: 0.0025
# Epoch 27/200
# 331/331 ━━━━━━━━━━━━━━━━━━━━ 5s 14ms/step - loss: 0.1440 - mae: 6.2164 - val_loss: 0.2158 - val_mae: 5.6323 - learning_rate: 0.0025
# Epoch 28/200
# 331/331 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - loss: 0.1452 - mae: 6.1956 - val_loss: 0.2151 - val_mae: 5.9986 - learning_rate: 0.0025
# Epoch 29/200
# 331/331 ━━━━━━━━━━━━━━━━━━━━ 8s 23ms/step - loss: 0.1428 - mae: 6.1687 - val_loss: 0.2073 - val_mae: 5.6603 - learning_rate: 0.0025
# Epoch 30/200
# 331/331 ━━━━━━━━━━━━━━━━━━━━ 9s 27ms/step - loss: 0.1381 - mae: 6.0358 - val_loss: 0.1947 - val_mae: 5.4750 - learning_rate: 0.0012
# Epoch 31/200
# 331/331 ━━━━━━━━━━━━━━━━━━━━ 6s 17ms/step - loss: 0.1358 - mae: 5.9503 - val_loss: 0.1957 - val_mae: 5.3427 - learning_rate: 0.0012
# Epoch 32/200
# 331/331 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - loss: 0.1376 - mae: 5.9881 - val_loss: 0.2005 - val_mae: 5.3579 - learning_rate: 0.0012
# Epoch 33/200
# 331/331 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - loss: 0.1321 - mae: 5.9337 - val_loss: 0.1962 - val_mae: 5.3887 - learning_rate: 0.0012
# Epoch 34/200
# 331/331 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - loss: 0.1312 - mae: 5.8670 - val_loss: 0.1983 - val_mae: 5.3298 - learning_rate: 0.0012
# Epoch 35/200
# 331/331 ━━━━━━━━━━━━━━━━━━━━ 5s 14ms/step - loss: 0.1319 - mae: 5.8773 - val_loss: 0.2020 - val_mae: 5.5693 - learning_rate: 0.0012
# Epoch 36/200
# 331/331 ━━━━━━━━━━━━━━━━━━━━ 5s 14ms/step - loss: 0.1296 - mae: 5.8723 - val_loss: 0.1898 - val_mae: 5.2890 - learning_rate: 6.2500e-04
# Epoch 37/200
# 331/331 ━━━━━━━━━━━━━━━━━━━━ 7s 21ms/step - loss: 0.1274 - mae: 5.7299 - val_loss: 0.1890 - val_mae: 5.2625 - learning_rate: 6.2500e-04
# Epoch 38/200
# 331/331 ━━━━━━━━━━━━━━━━━━━━ 6s 17ms/step - loss: 0.1265 - mae: 5.8151 - val_loss: 0.1927 - val_mae: 5.3218 - learning_rate: 6.2500e-04
# Epoch 39/200
# 331/331 ━━━━━━━━━━━━━━━━━━━━ 5s 14ms/step - loss: 0.1268 - mae: 5.8700 - val_loss: 0.1938 - val_mae: 5.2482 - learning_rate: 6.2500e-04
# Epoch 40/200
# 331/331 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - loss: 0.1284 - mae: 5.7711 - val_loss: 0.1923 - val_mae: 5.2724 - learning_rate: 6.2500e-04
# Epoch 41/200
# 331/331 ━━━━━━━━━━━━━━━━━━━━ 5s 13ms/step - loss: 0.1258 - mae: 5.7305 - val_loss: 0.1867 - val_mae: 5.2206 - learning_rate: 6.2500e-04
# Epoch 42/200
# 331/331 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - loss: 0.1280 - mae: 5.7408 - val_loss: 0.1885 - val_mae: 5.1909 - learning_rate: 6.2500e-04
# Epoch 43/200
# 331/331 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - loss: 0.1271 - mae: 5.7367 - val_loss: 0.1887 - val_mae: 5.2477 - learning_rate: 6.2500e-04
# Epoch 44/200
# 331/331 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 0.1267 - mae: 5.7009 - val_loss: 0.1854 - val_mae: 5.2192 - learning_rate: 6.2500e-04
# Epoch 45/200
# 331/331 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 0.1290 - mae: 5.7572 - val_loss: 0.1869 - val_mae: 5.1856 - learning_rate: 6.2500e-04
# Epoch 46/200
# 331/331 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 0.1249 - mae: 5.7069 - val_loss: 0.1892 - val_mae: 5.1881 - learning_rate: 6.2500e-04
# Epoch 47/200
# 331/331 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 0.1258 - mae: 5.7015 - val_loss: 0.1892 - val_mae: 5.2346 - learning_rate: 6.2500e-04
# Epoch 48/200
# 331/331 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 0.1243 - mae: 5.6693 - val_loss: 0.1868 - val_mae: 5.1776 - learning_rate: 6.2500e-04
# Epoch 49/200
# 331/331 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - loss: 0.1242 - mae: 5.6633 - val_loss: 0.1826 - val_mae: 5.1630 - learning_rate: 6.2500e-04
# Epoch 50/200
# 331/331 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 0.1243 - mae: 5.6362 - val_loss: 0.1885 - val_mae: 5.2580 - learning_rate: 6.2500e-04
# Epoch 51/200
# 331/331 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 0.1230 - mae: 5.6678 - val_loss: 0.1913 - val_mae: 5.2145 - learning_rate: 6.2500e-04
# Epoch 52/200
# 331/331 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 0.1254 - mae: 5.7501 - val_loss: 0.1889 - val_mae: 5.2271 - learning_rate: 6.2500e-04
# Epoch 53/200
# 331/331 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 0.1234 - mae: 5.6478 - val_loss: 0.1866 - val_mae: 5.1852 - learning_rate: 6.2500e-04
# Epoch 54/200
# 331/331 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 0.1227 - mae: 5.6618 - val_loss: 0.1880 - val_mae: 5.2073 - learning_rate: 6.2500e-04
# Epoch 55/200
# 331/331 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 0.1230 - mae: 5.6216 - val_loss: 0.1859 - val_mae: 5.1722 - learning_rate: 3.1250e-04
# Epoch 56/200
# 331/331 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 0.1204 - mae: 5.5726 - val_loss: 0.1819 - val_mae: 5.1904 - learning_rate: 3.1250e-04
# Epoch 57/200
# 331/331 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 0.1234 - mae: 5.5998 - val_loss: 0.1817 - val_mae: 5.1198 - learning_rate: 3.1250e-04
# Epoch 58/200
# 331/331 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 0.1227 - mae: 5.6724 - val_loss: 0.1819 - val_mae: 5.1104 - learning_rate: 3.1250e-04
# Epoch 59/200
# 331/331 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - loss: 0.1216 - mae: 5.5076 - val_loss: 0.1828 - val_mae: 5.1012 - learning_rate: 3.1250e-04
# Epoch 60/200
# 331/331 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - loss: 0.1220 - mae: 5.6144 - val_loss: 0.1811 - val_mae: 5.0977 - learning_rate: 3.1250e-04
# Epoch 61/200
# 331/331 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - loss: 0.1174 - mae: 5.5560 - val_loss: 0.1834 - val_mae: 5.0899 - learning_rate: 3.1250e-04
# Epoch 62/200
# 331/331 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - loss: 0.1187 - mae: 5.5581 - val_loss: 0.1820 - val_mae: 5.0883 - learning_rate: 3.1250e-04
# Epoch 63/200
# 331/331 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - loss: 0.1207 - mae: 5.5686 - val_loss: 0.1823 - val_mae: 5.1061 - learning_rate: 3.1250e-04
# Epoch 64/200
# 331/331 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - loss: 0.1203 - mae: 5.5585 - val_loss: 0.1808 - val_mae: 5.0931 - learning_rate: 3.1250e-04
# Epoch 65/200
# 331/331 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - loss: 0.1214 - mae: 5.5737 - val_loss: 0.1788 - val_mae: 5.1077 - learning_rate: 3.1250e-04
# Epoch 66/200
# 331/331 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - loss: 0.1190 - mae: 5.5325 - val_loss: 0.1817 - val_mae: 5.1028 - learning_rate: 3.1250e-04
# Epoch 67/200
# 331/331 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 0.1223 - mae: 5.6104 - val_loss: 0.1832 - val_mae: 5.1075 - learning_rate: 3.1250e-04
# Epoch 68/200
# 331/331 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 0.1187 - mae: 5.5431 - val_loss: 0.1822 - val_mae: 5.1198 - learning_rate: 3.1250e-04
# Epoch 69/200
# 331/331 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 0.1213 - mae: 5.6412 - val_loss: 0.1823 - val_mae: 5.1132 - learning_rate: 3.1250e-04
# Epoch 70/200
# 331/331 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 0.1202 - mae: 5.5400 - val_loss: 0.1821 - val_mae: 5.0742 - learning_rate: 3.1250e-04
# Epoch 71/200
# 331/331 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 0.1213 - mae: 5.5980 - val_loss: 0.1778 - val_mae: 5.0502 - learning_rate: 1.5625e-04
# Epoch 72/200
# 331/331 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 0.1180 - mae: 5.5188 - val_loss: 0.1801 - val_mae: 5.0551 - learning_rate: 1.5625e-04
# Epoch 73/200
# 331/331 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 0.1181 - mae: 5.4878 - val_loss: 0.1789 - val_mae: 5.0387 - learning_rate: 1.5625e-04
# Epoch 74/200
# 331/331 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - loss: 0.1182 - mae: 5.4416 - val_loss: 0.1794 - val_mae: 5.0759 - learning_rate: 1.5625e-04
# Epoch 75/200
# 331/331 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - loss: 0.1207 - mae: 5.5039 - val_loss: 0.1798 - val_mae: 5.0434 - learning_rate: 1.5625e-04
# Epoch 76/200
# 331/331 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 0.1202 - mae: 5.4845 - val_loss: 0.1796 - val_mae: 5.0426 - learning_rate: 1.5625e-04
# Epoch 77/200
# 331/331 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 0.1196 - mae: 5.5580 - val_loss: 0.1778 - val_mae: 5.0339 - learning_rate: 7.8125e-05
# Epoch 78/200
# 331/331 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 0.1174 - mae: 5.5092 - val_loss: 0.1776 - val_mae: 5.0245 - learning_rate: 7.8125e-05
# Epoch 79/200
# 331/331 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 0.1156 - mae: 5.5260 - val_loss: 0.1788 - val_mae: 5.0286 - learning_rate: 7.8125e-05
# Epoch 80/200
# 331/331 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 0.1151 - mae: 5.4963 - val_loss: 0.1788 - val_mae: 5.0242 - learning_rate: 7.8125e-05
# Epoch 81/200
# 331/331 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 0.1170 - mae: 5.5540 - val_loss: 0.1778 - val_mae: 5.0220 - learning_rate: 7.8125e-05
# Epoch 82/200
# 331/331 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 0.1192 - mae: 5.5641 - val_loss: 0.1778 - val_mae: 5.0369 - learning_rate: 7.8125e-05
# Epoch 83/200
# 331/331 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 0.1180 - mae: 5.4914 - val_loss: 0.1780 - val_mae: 5.0366 - learning_rate: 7.8125e-05
# Epoch 84/200
# 331/331 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 0.1178 - mae: 5.4771 - val_loss: 0.1778 - val_mae: 5.0262 - learning_rate: 3.9062e-05
# Epoch 85/200
# 331/331 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 0.1172 - mae: 5.4525 - val_loss: 0.1778 - val_mae: 5.0256 - learning_rate: 3.9062e-05
# Epoch 86/200
# 331/331 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 0.1186 - mae: 5.4649 - val_loss: 0.1777 - val_mae: 5.0250 - learning_rate: 3.9062e-05
# Epoch 87/200
# 331/331 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 0.1185 - mae: 5.5847 - val_loss: 0.1776 - val_mae: 5.0282 - learning_rate: 3.9062e-05
# Epoch 88/200
# 331/331 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - loss: 0.1173 - mae: 5.5138 - val_loss: 0.1774 - val_mae: 5.0199 - learning_rate: 3.9062e-05
# Epoch 89/200
# 331/331 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - loss: 0.1157 - mae: 5.4677 - val_loss: 0.1778 - val_mae: 5.0278 - learning_rate: 3.9062e-05
# Epoch 90/200
# 331/331 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - loss: 0.1161 - mae: 5.4637 - val_loss: 0.1777 - val_mae: 5.0241 - learning_rate: 3.9062e-05
# Epoch 91/200
# 331/331 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - loss: 0.1172 - mae: 5.4702 - val_loss: 0.1779 - val_mae: 5.0220 - learning_rate: 3.9062e-05
# Epoch 92/200
# 331/331 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - loss: 0.1174 - mae: 5.4574 - val_loss: 0.1776 - val_mae: 5.0158 - learning_rate: 3.9062e-05
# Epoch 93/200
# 331/331 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - loss: 0.1177 - mae: 5.4908 - val_loss: 0.1773 - val_mae: 5.0249 - learning_rate: 3.9062e-05
# Epoch 94/200
# 331/331 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - loss: 0.1175 - mae: 5.5299 - val_loss: 0.1779 - val_mae: 5.0235 - learning_rate: 1.9531e-05
# Epoch 95/200
# 331/331 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - loss: 0.1175 - mae: 5.4912 - val_loss: 0.1776 - val_mae: 5.0175 - learning_rate: 1.9531e-05
# Epoch 96/200
# 331/331 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - loss: 0.1162 - mae: 5.4467 - val_loss: 0.1779 - val_mae: 5.0230 - learning_rate: 1.9531e-05
# Epoch 97/200
# 331/331 ━━━━━━━━━━━━━━━━━━━━ 5s 14ms/step - loss: 0.1197 - mae: 5.4688 - val_loss: 0.1770 - val_mae: 5.0160 - learning_rate: 1.9531e-05
# Epoch 98/200
# 331/331 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - loss: 0.1187 - mae: 5.5271 - val_loss: 0.1771 - val_mae: 5.0156 - learning_rate: 1.9531e-05
# Epoch 99/200
# 331/331 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 0.1158 - mae: 5.4700 - val_loss: 0.1779 - val_mae: 5.0189 - learning_rate: 1.9531e-05
# Epoch 100/200
# 331/331 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 0.1151 - mae: 5.4462 - val_loss: 0.1771 - val_mae: 5.0140 - learning_rate: 1.9531e-05
# Epoch 101/200
# 331/331 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 0.1189 - mae: 5.4919 - val_loss: 0.1777 - val_mae: 5.0133 - learning_rate: 1.9531e-05
# Epoch 102/200
# 331/331 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 0.1177 - mae: 5.5249 - val_loss: 0.1777 - val_mae: 5.0174 - learning_rate: 1.9531e-05
# Epoch 103/200
# 331/331 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 0.1188 - mae: 5.4906 - val_loss: 0.1776 - val_mae: 5.0151 - learning_rate: 9.7656e-06
# Epoch 104/200
# 331/331 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 0.1168 - mae: 5.5028 - val_loss: 0.1775 - val_mae: 5.0140 - learning_rate: 9.7656e-06
# Epoch 105/200
# 331/331 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 0.1150 - mae: 5.4359 - val_loss: 0.1772 - val_mae: 5.0124 - learning_rate: 9.7656e-06
# Epoch 106/200
# 331/331 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 0.1180 - mae: 5.4902 - val_loss: 0.1775 - val_mae: 5.0122 - learning_rate: 9.7656e-06
# Epoch 107/200
# 331/331 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - loss: 0.1173 - mae: 5.4827 - val_loss: 0.1771 - val_mae: 5.0125 - learning_rate: 9.7656e-06
# Epoch 108/200
# 331/331 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - loss: 0.1160 - mae: 5.5050 - val_loss: 0.1772 - val_mae: 5.0172 - learning_rate: 4.8828e-06
# Epoch 109/200
# 331/331 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - loss: 0.1169 - mae: 5.4923 - val_loss: 0.1773 - val_mae: 5.0132 - learning_rate: 4.8828e-06
# Epoch 110/200
# 331/331 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - loss: 0.1158 - mae: 5.5099 - val_loss: 0.1772 - val_mae: 5.0092 - learning_rate: 4.8828e-06
# Epoch 111/200
# 331/331 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 0.1183 - mae: 5.5285 - val_loss: 0.1773 - val_mae: 5.0119 - learning_rate: 4.8828e-06
# Epoch 112/200
# 331/331 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 0.1152 - mae: 5.4617 - val_loss: 0.1776 - val_mae: 5.0143 - learning_rate: 4.8828e-06
# Epoch 113/200
# 331/331 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - loss: 0.1157 - mae: 5.4602 - val_loss: 0.1774 - val_mae: 5.0125 - learning_rate: 2.4414e-06
# Epoch 114/200
# 331/331 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.1180 - mae: 5.5253 - val_loss: 0.1776 - val_mae: 5.0125 - learning_rate: 2.4414e-06
# Epoch 115/200
# 331/331 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - loss: 0.1189 - mae: 5.5130 - val_loss: 0.1776 - val_mae: 5.0146 - learning_rate: 2.4414e-06
# Epoch 116/200
# 331/331 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 0.1169 - mae: 5.4745 - val_loss: 0.1773 - val_mae: 5.0129 - learning_rate: 2.4414e-06
# Epoch 117/200
# 331/331 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - loss: 0.1180 - mae: 5.4465 - val_loss: 0.1771 - val_mae: 5.0092 - learning_rate: 2.4414e-06
# Epoch 118/200
# 331/331 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - loss: 0.1170 - mae: 5.4853 - val_loss: 0.1776 - val_mae: 5.0130 - learning_rate: 1.2207e-06
# Epoch 119/200
# 331/331 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - loss: 0.1179 - mae: 5.4973 - val_loss: 0.1778 - val_mae: 5.0151 - learning_rate: 1.2207e-06
# Epoch 120/200
# 331/331 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - loss: 0.1190 - mae: 5.4819 - val_loss: 0.1773 - val_mae: 5.0136 - learning_rate: 1.2207e-06
# Epoch 121/200
# 331/331 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - loss: 0.1184 - mae: 5.5211 - val_loss: 0.1775 - val_mae: 5.0153 - learning_rate: 1.2207e-06
# Epoch 122/200
# 331/331 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - loss: 0.1192 - mae: 5.5423 - val_loss: 0.1772 - val_mae: 5.0132 - learning_rate: 1.2207e-06
# Epoch 123/200
# 331/331 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - loss: 0.1158 - mae: 5.4385 - val_loss: 0.1772 - val_mae: 5.0128 - learning_rate: 1.0000e-06
# Epoch 124/200
# 331/331 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - loss: 0.1171 - mae: 5.4925 - val_loss: 0.1773 - val_mae: 5.0103 - learning_rate: 1.0000e-06
# Epoch 125/200
# 331/331 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - loss: 0.1170 - mae: 5.4749 - val_loss: 0.1773 - val_mae: 5.0125 - learning_rate: 1.0000e-06
# Epoch 126/200
# 331/331 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - loss: 0.1191 - mae: 5.5128 - val_loss: 0.1774 - val_mae: 5.0130 - learning_rate: 1.0000e-06
# Epoch 127/200
# 331/331 ━━━━━━━━━━━━━━━━━━━━ 5s 14ms/step - loss: 0.1169 - mae: 5.4301 - val_loss: 0.1773 - val_mae: 5.0144 - learning_rate: 1.0000e-06
# Epoch 128/200
# 331/331 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - loss: 0.1166 - mae: 5.4739 - val_loss: 0.1772 - val_mae: 5.0113 - learning_rate: 1.0000e-06
# Epoch 129/200
# 331/331 ━━━━━━━━━━━━━━━━━━━━ 12s 35ms/step - loss: 0.1166 - mae: 5.4446 - val_loss: 0.1774 - val_mae: 5.0111 - learning_rate: 1.0000e-06
# Epoch 130/200
# 331/331 ━━━━━━━━━━━━━━━━━━━━ 14s 16ms/step - loss: 0.1151 - mae: 5.4205 - val_loss: 0.1772 - val_mae: 5.0147 - learning_rate: 1.0000e-06
# Epoch 131/200
# 331/331 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - loss: 0.1164 - mae: 5.5016 - val_loss: 0.1777 - val_mae: 5.0170 - learning_rate: 1.0000e-06
# Epoch 132/200
# 331/331 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - loss: 0.1171 - mae: 5.4579 - val_loss: 0.1771 - val_mae: 5.0102 - learning_rate: 1.0000e-06
# Epoch 133/200
# 331/331 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 0.1163 - mae: 5.4588 - val_loss: 0.1774 - val_mae: 5.0125 - learning_rate: 1.0000e-06
# Epoch 134/200
# 331/331 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 0.1190 - mae: 5.5492 - val_loss: 0.1774 - val_mae: 5.0157 - learning_rate: 1.0000e-06
# Epoch 135/200
# 331/331 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 0.1183 - mae: 5.5618 - val_loss: 0.1772 - val_mae: 5.0142 - learning_rate: 1.0000e-06
# Epoch 136/200
# 331/331 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 0.1187 - mae: 5.4446 - val_loss: 0.1774 - val_mae: 5.0102 - learning_rate: 1.0000e-06
# Epoch 137/200
# 331/331 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 0.1163 - mae: 5.4096 - val_loss: 0.1773 - val_mae: 5.0122 - learning_rate: 1.0000e-06
# Epoch 138/200
# 331/331 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 0.1163 - mae: 5.4314 - val_loss: 0.1772 - val_mae: 5.0152 - learning_rate: 1.0000e-06
# Epoch 139/200
# 331/331 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 0.1161 - mae: 5.5567 - val_loss: 0.1775 - val_mae: 5.0215 - learning_rate: 1.0000e-06
# Epoch 140/200
# 331/331 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 0.1170 - mae: 5.4789 - val_loss: 0.1768 - val_mae: 5.0101 - learning_rate: 1.0000e-06
# Epoch 141/200
# 331/331 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 0.1160 - mae: 5.4817 - val_loss: 0.1774 - val_mae: 5.0161 - learning_rate: 1.0000e-06
# Epoch 142/200
# 331/331 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 0.1178 - mae: 5.5206 - val_loss: 0.1775 - val_mae: 5.0072 - learning_rate: 1.0000e-06
# Epoch 143/200
# 331/331 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 0.1170 - mae: 5.4302 - val_loss: 0.1773 - val_mae: 5.0082 - learning_rate: 1.0000e-06
# Epoch 144/200
# 331/331 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 0.1189 - mae: 5.5143 - val_loss: 0.1775 - val_mae: 5.0210 - learning_rate: 1.0000e-06
# Epoch 145/200
# 331/331 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 0.1163 - mae: 5.4424 - val_loss: 0.1773 - val_mae: 5.0084 - learning_rate: 1.0000e-06
# Epoch 146/200
# 331/331 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 0.1182 - mae: 5.4519 - val_loss: 0.1774 - val_mae: 5.0121 - learning_rate: 1.0000e-06
# Epoch 147/200
# 331/331 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 0.1184 - mae: 5.5042 - val_loss: 0.1775 - val_mae: 5.0102 - learning_rate: 1.0000e-06
# Epoch 148/200
# 331/331 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 0.1153 - mae: 5.4090 - val_loss: 0.1772 - val_mae: 5.0087 - learning_rate: 1.0000e-06
# Epoch 149/200
# 331/331 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.1177 - mae: 5.4723 - val_loss: 0.1774 - val_mae: 5.0156 - learning_rate: 1.0000e-06
# Epoch 150/200
# 331/331 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - loss: 0.1183 - mae: 5.5413 - val_loss: 0.1775 - val_mae: 5.0135 - learning_rate: 1.0000e-06
# Epoch 151/200
# 331/331 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 0.1162 - mae: 5.4138 - val_loss: 0.1776 - val_mae: 5.0148 - learning_rate: 1.0000e-06
# Epoch 152/200
# 331/331 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 0.1181 - mae: 5.4400 - val_loss: 0.1771 - val_mae: 5.0093 - learning_rate: 1.0000e-06
# Epoch 153/200
# 331/331 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - loss: 0.1150 - mae: 5.4337 - val_loss: 0.1775 - val_mae: 5.0109 - learning_rate: 1.0000e-06
# Epoch 154/200
# 331/331 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - loss: 0.1139 - mae: 5.4153 - val_loss: 0.1774 - val_mae: 5.0121 - learning_rate: 1.0000e-06
# Epoch 155/200
# 331/331 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - loss: 0.1168 - mae: 5.4468 - val_loss: 0.1774 - val_mae: 5.0164 - learning_rate: 1.0000e-06
# Epoch 156/200
# 331/331 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 0.1185 - mae: 5.4455 - val_loss: 0.1777 - val_mae: 5.0126 - learning_rate: 1.0000e-06
# Epoch 157/200
# 331/331 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 0.1193 - mae: 5.4811 - val_loss: 0.1774 - val_mae: 5.0104 - learning_rate: 1.0000e-06
# Epoch 158/200
# 331/331 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 0.1170 - mae: 5.4441 - val_loss: 0.1775 - val_mae: 5.0135 - learning_rate: 1.0000e-06
# Epoch 159/200
# 331/331 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 0.1198 - mae: 5.5413 - val_loss: 0.1773 - val_mae: 5.0097 - learning_rate: 1.0000e-06
# Epoch 160/200
# 331/331 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 0.1159 - mae: 5.4975 - val_loss: 0.1773 - val_mae: 5.0112 - learning_rate: 1.0000e-06
# Epoch 161/200
# 331/331 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - loss: 0.1188 - mae: 5.5125 - val_loss: 0.1774 - val_mae: 5.0120 - learning_rate: 1.0000e-06
# Epoch 162/200
# 331/331 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - loss: 0.1159 - mae: 5.4647 - val_loss: 0.1779 - val_mae: 5.0122 - learning_rate: 1.0000e-06
# Epoch 163/200
# 331/331 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.1161 - mae: 5.5023 - val_loss: 0.1774 - val_mae: 5.0160 - learning_rate: 1.0000e-06
# Epoch 164/200
# 331/331 ━━━━━━━━━━━━━━━━━━━━ 6s 18ms/step - loss: 0.1166 - mae: 5.4845 - val_loss: 0.1773 - val_mae: 5.0160 - learning_rate: 1.0000e-06
# Epoch 165/200
# 331/331 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.1162 - mae: 5.4604 - val_loss: 0.1772 - val_mae: 5.0174 - learning_rate: 1.0000e-06
# Epoch 166/200
# 331/331 ━━━━━━━━━━━━━━━━━━━━ 5s 14ms/step - loss: 0.1199 - mae: 5.5583 - val_loss: 0.1779 - val_mae: 5.0167 - learning_rate: 1.0000e-06
# Epoch 167/200
# 331/331 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - loss: 0.1181 - mae: 5.4571 - val_loss: 0.1777 - val_mae: 5.0149 - learning_rate: 1.0000e-06
# Epoch 168/200
# 331/331 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 0.1159 - mae: 5.4683 - val_loss: 0.1774 - val_mae: 5.0200 - learning_rate: 1.0000e-06
# Epoch 169/200
# 331/331 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 0.1176 - mae: 5.5065 - val_loss: 0.1777 - val_mae: 5.0176 - learning_rate: 1.0000e-06
# Epoch 170/200
# 331/331 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 0.1165 - mae: 5.4157 - val_loss: 0.1772 - val_mae: 5.0108 - learning_rate: 1.0000e-06
# Epoch 171/200
# 331/331 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 0.1166 - mae: 5.4417 - val_loss: 0.1777 - val_mae: 5.0129 - learning_rate: 1.0000e-06
# Epoch 172/200
# 331/331 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 0.1173 - mae: 5.4435 - val_loss: 0.1775 - val_mae: 5.0136 - learning_rate: 1.0000e-06
# Epoch 173/200
# 331/331 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 0.1143 - mae: 5.4223 - val_loss: 0.1770 - val_mae: 5.0092 - learning_rate: 1.0000e-06
# Epoch 174/200
# 331/331 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 0.1135 - mae: 5.3413 - val_loss: 0.1774 - val_mae: 5.0106 - learning_rate: 1.0000e-06
# Epoch 175/200
# 331/331 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 0.1196 - mae: 5.5340 - val_loss: 0.1768 - val_mae: 5.0079 - learning_rate: 1.0000e-06
# Epoch 176/200
# 331/331 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 0.1173 - mae: 5.4652 - val_loss: 0.1771 - val_mae: 5.0114 - learning_rate: 1.0000e-06
# Epoch 177/200
# 331/331 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 0.1192 - mae: 5.4911 - val_loss: 0.1773 - val_mae: 5.0153 - learning_rate: 1.0000e-06
# Epoch 178/200
# 331/331 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - loss: 0.1166 - mae: 5.4603 - val_loss: 0.1770 - val_mae: 5.0067 - learning_rate: 1.0000e-06
# Epoch 179/200
# 331/331 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - loss: 0.1158 - mae: 5.4996 - val_loss: 0.1771 - val_mae: 5.0130 - learning_rate: 1.0000e-06
# Epoch 180/200
# 331/331 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - loss: 0.1187 - mae: 5.5179 - val_loss: 0.1775 - val_mae: 5.0162 - learning_rate: 1.0000e-06
# Epoch 181/200
# 331/331 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - loss: 0.1161 - mae: 5.4572 - val_loss: 0.1775 - val_mae: 5.0175 - learning_rate: 1.0000e-06
# Epoch 182/200
# 331/331 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - loss: 0.1190 - mae: 5.5009 - val_loss: 0.1777 - val_mae: 5.0149 - learning_rate: 1.0000e-06
# Epoch 183/200
# 331/331 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - loss: 0.1147 - mae: 5.4472 - val_loss: 0.1775 - val_mae: 5.0100 - learning_rate: 1.0000e-06
# Epoch 184/200
# 331/331 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - loss: 0.1171 - mae: 5.4534 - val_loss: 0.1771 - val_mae: 5.0100 - learning_rate: 1.0000e-06
# Epoch 185/200
# 331/331 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - loss: 0.1200 - mae: 5.5233 - val_loss: 0.1776 - val_mae: 5.0176 - learning_rate: 1.0000e-06
# Epoch 186/200
# 331/331 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - loss: 0.1162 - mae: 5.4162 - val_loss: 0.1775 - val_mae: 5.0140 - learning_rate: 1.0000e-06
# Epoch 187/200
# 331/331 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - loss: 0.1159 - mae: 5.5083 - val_loss: 0.1772 - val_mae: 5.0133 - learning_rate: 1.0000e-06
# Epoch 188/200
# 331/331 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - loss: 0.1187 - mae: 5.4841 - val_loss: 0.1773 - val_mae: 5.0125 - learning_rate: 1.0000e-06
# Epoch 189/200
# 331/331 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - loss: 0.1163 - mae: 5.4484 - val_loss: 0.1773 - val_mae: 5.0145 - learning_rate: 1.0000e-06
# Epoch 190/200
# 331/331 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - loss: 0.1168 - mae: 5.4888 - val_loss: 0.1775 - val_mae: 5.0135 - learning_rate: 1.0000e-06
# Epoch 191/200
# 331/331 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.1160 - mae: 5.4071 - val_loss: 0.1771 - val_mae: 5.0159 - learning_rate: 1.0000e-06
# Epoch 192/200
# 331/331 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - loss: 0.1156 - mae: 5.3983 - val_loss: 0.1771 - val_mae: 5.0131 - learning_rate: 1.0000e-06
# Epoch 193/200
# 331/331 ━━━━━━━━━━━━━━━━━━━━ 7781s 24s/step - loss: 0.1150 - mae: 5.4352 - val_loss: 0.1773 - val_mae: 5.0101 - learning_rate: 1.0000e-06
# Epoch 194/200
# 331/331 ━━━━━━━━━━━━━━━━━━━━ 10224s 31s/step - loss: 0.1182 - mae: 5.5327 - val_loss: 0.1771 - val_mae: 5.0149 - learning_rate: 1.0000e-06
# Epoch 195/200
# 331/331 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - loss: 0.1157 - mae: 5.4419 - val_loss: 0.1771 - val_mae: 5.0124 - learning_rate: 1.0000e-06
# Epoch 196/200
# 331/331 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - loss: 0.1171 - mae: 5.5206 - val_loss: 0.1774 - val_mae: 5.0151 - learning_rate: 1.0000e-06
# Epoch 197/200
# 331/331 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - loss: 0.1174 - mae: 5.4618 - val_loss: 0.1777 - val_mae: 5.0158 - learning_rate: 1.0000e-06
# Epoch 198/200
# 331/331 ━━━━━━━━━━━━━━━━━━━━ 37190s 113s/step - loss: 0.1202 - mae: 5.4889 - val_loss: 0.1776 - val_mae: 5.0119 - learning_rate: 1.0000e-06
# Epoch 199/200
# 331/331 ━━━━━━━━━━━━━━━━━━━━ 8s 23ms/step - loss: 0.1181 - mae: 5.4824 - val_loss: 0.1776 - val_mae: 5.0100 - learning_rate: 1.0000e-06
# Epoch 200/200
# 331/331 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - loss: 0.1164 - mae: 5.4766 - val_loss: 0.1771 - val_mae: 5.0122 - learning_rate: 1.0000e-06

# %%
# Evaluate on test set
loss, mae = model.evaluate([X_test_num, X_test_em], y_test)
print(f"Test Loss: {loss:.4f}, Test MAE: {mae:.4f}")
# Out:
# 331/331 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.1834 - mae: 5.1009
# Test Loss: 0.1771, Test MAE: 5.0122

# %%
y_pred = model.predict([X_test_num, X_test_em])
mae_entries = np.mean(np.abs(y_test[:,0] - y_pred[:,0]))
mae_exits   = np.mean(np.abs(y_test[:,1] - y_pred[:,1]))
print(f"Entries MAE: {mae_entries:.4f} | Exits MAE: {mae_exits:.4f}")
# Out:
# 331/331 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step
# Entries MAE: 5.2956 | Exits MAE: 4.7288

# %%
# Plot for each target
for i, label in enumerate(target_col):
    plt.figure(figsize=(10,5))
    r2 = r2_score(y_test[:,i], y_pred[:,i])
    plt.scatter(y_test[:,i], y_pred[:,i], alpha=0.4)
    lims = [min(y_test[:,i].min(), y_pred[:,i].min()),
            max(y_test[:,i].max(), y_pred[:,i].max())]
    plt.plot(lims, lims, 'r--')
    plt.title(f"Actual vs Predicted: {label}")
    plt.annotate(f'$R^2 = {r2:.2f}$', xy=(0.05, 0.95),xycoords='axes fraction',fontsize=12,color='blue', verticalalignment='top')
    plt.xlabel("Actual")
    plt.ylabel("Predicted")
    plt.show()

# %%
#Visualize predicted vs real number of people per stop on test set

# %%
# Flatten arrays
y_test_flat = y_test.flatten()
y_pred_flat = y_pred.flatten()

# Plot actual vs. predicted values
plt.figure(figsize=(10, 5))
plt.plot(y_test_flat, label="Actual", marker='o', linestyle='dashed')
plt.plot(y_pred_flat, label="Predicted", marker='o', linestyle='dashed')
plt.xlabel("Sorted Sample Index (Descending True Value)")
plt.ylabel("Number of People")
plt.title("Actual vs. Predicted Number of People")
plt.legend()
plt.grid(True)
plt.show()

# %%
# Sort indices based on decreasing actual values
sorted_indices = np.argsort(-y_test_flat)  # Negative sign to sort in decreasing order

# Apply sorting
y_test_sorted = y_test_flat[sorted_indices]
y_pred_sorted = y_pred_flat[sorted_indices]

# Plot actual vs. predicted values
plt.figure(figsize=(10, 5))
plt.plot(y_test_sorted, label="Actual", marker='o', linestyle='dashed',alpha=0.9)
plt.plot(y_pred_sorted, label="Predicted", marker='o', linestyle='dashed',alpha=0.05)
plt.xlabel("Sorted Sample Index (Descending True Value)")
plt.ylabel("Number of People")
plt.title("Actual vs. Predicted Number of People (Sorted by Decreasing Actual Value)")
plt.legend()
plt.grid(True)
plt.show()

# %%
# -------------------------------------------------------
# Predict on a new sample
# -------------------------------------------------------
sample_num = np.array([[0.5, 0.3]], dtype="float32")
sample_em  = np.array([[100]], dtype="int32")
pred_sample = model.predict([sample_num, sample_em])[0]                               
print(f"Predicted entries: {pred_sample[0]:.1f}, exits: {pred_sample[1]:.1f}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 413ms/step
# Predicted entries: 11.1, exits: 10.7

# %% [markdown]
# #######################################################################

# %%
#######################################################################

# %% [markdown]
# ### Save model

# %%
model.save('NN_En_Ex.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %% [markdown]
# ### Quantitative Analysis:

# %% [markdown]
# Unitary results

# %%
# Get back the original unscaled features for the test set
X_test_original = X_test.copy()
X_test_original[num_cols] = scaler.inverse_transform(X_test[num_cols])  # unscale

# Build DataFrames
df_num = X_test_original[num_cols].reset_index(drop=True)
df_em = X_test_original[em_col].reset_index(drop=True)  # already not scaled
df_y_test = pd.DataFrame(y_test_raw, columns=['y_true_entries', 'y_true_exits']).reset_index(drop=True)
df_y_pred = pd.DataFrame(y_pred, columns=['y_pred_entries', 'y_pred_exits']).reset_index(drop=True)

# Combine all into one
df_all_unscaled = pd.concat([df_num, df_em, df_y_test, df_y_pred], axis=1)
df_all_unscaled.head()
# Out:
#    datetime_day_week  datetime_W  zone_codes  y_true_entries  y_true_exits  \
# 0                3.0        64.0          36        2.000000      2.000000
# 1                5.0        80.0          93        5.636364      4.636364
# 2                7.0        69.0           9        2.888889      2.666667
# 3                5.0        73.0          43       35.642857     31.785715
# 4                5.0        18.0         119        1.000000      0.500000
#
#    y_pred_entries  y_pred_exits
# 0        4.195545      4.010705
# 1        3.260321      3.074721
# 2        4.371271      4.072470
# 3       29.112879     24.998581
# 4        2.055966      1.851573

# %%
from sklearn.metrics import mean_absolute_error

def evaluate_multidim_outputs_by_group(df, group_col, y_true_cols, y_pred_cols, metric_func):
    results = []
    for group, group_df in df.groupby(group_col):
        entry_score = metric_func(group_df[y_true_cols[0]], group_df[y_pred_cols[0]])
        exit_score = metric_func(group_df[y_true_cols[1]], group_df[y_pred_cols[1]])
        results.append({
            group_col: group,
            f'{y_true_cols[0]}_score': entry_score,
            f'{y_true_cols[1]}_score': exit_score
        })
    return pd.DataFrame(results)

mae_by_day_week = evaluate_multidim_outputs_by_group(
    df_all_unscaled, group_col='datetime_day_week',
    y_true_cols=['y_true_entries', 'y_true_exits'],
    y_pred_cols=['y_pred_entries', 'y_pred_exits'],
    metric_func=mean_absolute_error
)
mae_by_datetime_W = evaluate_multidim_outputs_by_group(
    df_all_unscaled, group_col='datetime_W',
    y_true_cols=['y_true_entries', 'y_true_exits'],
    y_pred_cols=['y_pred_entries', 'y_pred_exits'],
    metric_func=mean_absolute_error
)
mae_by_zone_codes = evaluate_multidim_outputs_by_group(
    df_all_unscaled, group_col='zone_codes',
    y_true_cols=['y_true_entries', 'y_true_exits'],
    y_pred_cols=['y_pred_entries', 'y_pred_exits'],
    metric_func=mean_absolute_error
)
print(mae_by_day_week, mae_by_datetime_W, mae_by_zone_codes)
# Out:
#    datetime_day_week  y_true_entries_score  y_true_exits_score
# 0                1.0              5.295033            4.720369
# 1                2.0              5.086748            4.628552
# 2                3.0              5.346359            4.767142
# 3                4.0              5.526356            4.944904
# 4                5.0              5.486233            4.882710
# 5                6.0              5.764511            5.125236
# 6                7.0              4.573494            4.031384     datetime_W  y_true_entries_score  y_true_exits_score
# 0         10.0              1.163572            1.590241
# 1         13.0              0.993334            0.712741
# 2         14.0              1.452627            1.334429
# 3         15.0              1.855402            1.601543
# 4         16.0              0.869629            0.947370
# ..         ...                   ...                 ...
# 77        89.0              0.972046            1.016165
# 78        90.0              6.432464            5.735271
# 79        91.0              7.198783            7.262082
# 80        92.0              0.807810            0.080222
# 81        93.0              1.027305            0.841113
#
# [82 rows x 3 columns]      zone_codes  y_true_entries_score  y_true_exits_score
# 0             0              1.873366            1.758799
# 1             1              4.360874            4.226568
# 2             2              2.899286            2.681206
# 3             3              7.865887            7.005564
# 4             4              1.968500            1.838001
# ..          ...                   ...                 ...
# 128         128              3.158345            2.969235
# 129         129              2.381322            2.286382
# 130         130              1.632790            0.991936
# 131         131              1.751686            1.640995
# 132         132              3.409647            3.177446
#
# [133 rows x 3 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 5))
sns.lineplot(data=mae_by_day_week, x='datetime_day_week', y='y_true_entries_score', label='Entries', marker='o')
sns.lineplot(data=mae_by_day_week, x='datetime_day_week', y='y_true_exits_score', label='Exits', marker='o')
plt.title('MAE by datetime_day_week')
plt.xlabel('Day')
plt.ylabel('MAE')
plt.legend()
plt.tight_layout()
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 5))
sns.lineplot(data=mae_by_datetime_W, x='datetime_W', y='y_true_entries_score', label='Entries', marker='o')
sns.lineplot(data=mae_by_datetime_W, x='datetime_W', y='y_true_exits_score', label='Exits', marker='o')
plt.title('MAE by mae_by_datetime_W')
plt.xlabel('Datetime Window')
plt.ylabel('MAE')
plt.legend()
plt.tight_layout()
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 5))
sns.lineplot(data=mae_by_zone_codes, x='zone_codes', y='y_true_entries_score', label='Entries', marker='o')
sns.lineplot(data=mae_by_zone_codes, x='zone_codes', y='y_true_exits_score', label='Exits', marker='o')
plt.title('MAE by zone_codes')
plt.xlabel('Zone Code')
plt.ylabel('MAE')
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# Intersectional result

# %%
# Helper function (already fixed for multiple group columns)
from sklearn.metrics import mean_absolute_error

def evaluate_multidim_outputs_by_group(df, group_col, y_true_cols, y_pred_cols, metric_func):
    results = []
    for group, group_df in df.groupby(group_col):
        entry_score = metric_func(group_df[y_true_cols[0]], group_df[y_pred_cols[0]])
        exit_score = metric_func(group_df[y_true_cols[1]], group_df[y_pred_cols[1]])
        
        # Handle single vs multiple grouping columns
        if isinstance(group, tuple):
            group_dict = {col: val for col, val in zip(group_col, group)}
        else:
            group_dict = {group_col: group}
        
        group_dict.update({
            f'{y_true_cols[0]}_score': entry_score,
            f'{y_true_cols[1]}_score': exit_score
        })
        results.append(group_dict)
    
    return pd.DataFrame(results)

# 1. Zone × Day of Week
mae_by_zone_day = evaluate_multidim_outputs_by_group(
    df_all_unscaled,
    group_col=['zone_codes','datetime_day_week'],
    y_true_cols=['y_true_entries','y_true_exits'],
    y_pred_cols=['y_pred_entries','y_pred_exits'],
    metric_func=mean_absolute_error
)

# 2. Zone × Time Window
mae_by_zone_time = evaluate_multidim_outputs_by_group(
    df_all_unscaled,
    group_col=['zone_codes','datetime_W'],
    y_true_cols=['y_true_entries','y_true_exits'],
    y_pred_cols=['y_pred_entries','y_pred_exits'],
    metric_func=mean_absolute_error
)

# 3. Day of Week × Time Window
mae_by_day_time = evaluate_multidim_outputs_by_group(
    df_all_unscaled,
    group_col=['datetime_day_week','datetime_W'],
    y_true_cols=['y_true_entries','y_true_exits'],
    y_pred_cols=['y_pred_entries','y_pred_exits'],
    metric_func=mean_absolute_error
)

# Show previews
print("Zone × Day of Week:\n", mae_by_zone_day.head(10))
print("Zone × Time Window:\n", mae_by_zone_time.head(10))
print("Day of Week × Time Window:\n", mae_by_day_time.head(10))
# Out:
# Zone × Day of Week:
#     zone_codes  datetime_day_week  y_true_entries_score  y_true_exits_score
# 0           0                1.0              2.168679            2.094001
# 1           0                2.0              1.546949            1.317632
# 2           0                3.0              2.686394            2.547713
# 3           0                4.0              2.045203            1.852513
# 4           0                5.0              2.056967            2.021225
# 5           0                6.0              1.572039            1.520867
# 6           0                7.0              0.961412            0.836210
# 7           1                1.0              5.162105            4.939957
# 8           1                2.0              5.157670            4.979734
# 9           1                3.0              4.071763            4.117407
# Zone × Time Window:
#     zone_codes  datetime_W  y_true_entries_score  y_true_exits_score
# 0           0        25.0              0.485037            0.859136
# 1           0        26.0              0.513637            0.311136
# 2           0        27.0              0.880378            0.602954
# 3           0        29.0              0.947833            0.875312
# 4           0        30.0              1.293709            1.218226
# 5           0        31.0              1.624887            1.742733
# 6           0        32.0              1.187871            1.379879
# 7           0        37.0              2.162781            2.017615
# 8           0        38.0              4.382917            4.265800
# 9           0        44.0              0.926754            0.945061
# Day of Week × Time Window:
#     datetime_day_week  datetime_W  y_true_entries_score  y_true_exits_score
# 0                1.0        15.0              0.650863            0.947873
# 1                1.0        16.0              1.397383            1.078028
# 2                1.0        17.0             10.142298            9.920877
# 3                1.0        18.0              8.087177            7.015468
# 4                1.0        19.0              1.089621            0.904716
# 5                1.0        20.0              0.970189            0.988979
# 6                1.0        21.0              1.600101            1.362400
# 7                1.0        22.0              3.399939            2.721235
# 8                1.0        23.0              2.730574            2.272862
# 9                1.0        24.0              3.881651            3.244272

# %%
# Ensure day-of-week is integer [0–6]
mae_by_zone_day["datetime_day_week"] = mae_by_zone_day["datetime_day_week"].round().astype(int)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# 1. Zone × Day of Week
pivot_zone_day_entries = mae_by_zone_day.pivot(index="zone_codes", columns="datetime_day_week", values="y_true_entries_score")
pivot_zone_day_exits   = mae_by_zone_day.pivot(index="zone_codes", columns="datetime_day_week", values="y_true_exits_score")

def format_axis_ticks(ax, decimals=0):
    """Round tick labels on both axes"""
    ax.set_xticklabels([f"{tick:.{decimals}f}" if isinstance(tick, (int,float)) else tick for tick in ax.get_xticks()])
    ax.set_yticklabels([f"{tick:.{decimals}f}" if isinstance(tick, (int,float)) else tick for tick in ax.get_yticks()])

# Example: Zone × Day (Entries)
plt.figure(figsize=(12, 6))
ax = sns.heatmap(pivot_zone_day_entries, cmap="YlGnBu", annot=False)
plt.title("Entries MAE by Zone × Day of Week")
plt.xlabel("Day of Week")
plt.ylabel("Zone")
# format_axis_ticks(ax, decimals=0)   # round to integers
plt.show()

plt.figure(figsize=(12, 6))
ax = sns.heatmap(pivot_zone_day_exits, cmap="YlOrRd", annot=False)
plt.title("Exits MAE by Zone × Day of Week")
plt.xlabel("Day of Week")
plt.ylabel("Zone")
# format_axis_ticks(ax, decimals=0)   # round to integers
plt.show()


# 2. Zone × Time Window
pivot_zone_time_entries = mae_by_zone_time.pivot(index="zone_codes", columns="datetime_W", values="y_true_entries_score")
pivot_zone_time_exits   = mae_by_zone_time.pivot(index="zone_codes", columns="datetime_W", values="y_true_exits_score")

plt.figure(figsize=(12, 6))
ax = sns.heatmap(pivot_zone_time_entries, cmap="YlGnBu", annot=False)
plt.title("Entries MAE by Zone × Time Window")
plt.xlabel("Time Window")
plt.ylabel("Zone")
format_axis_ticks(ax, decimals=0)   # round to integers
plt.show()

plt.figure(figsize=(12, 6))
ax = sns.heatmap(pivot_zone_time_exits, cmap="YlOrRd", annot=False)
plt.title("Exits MAE by Zone × Time Window")
plt.xlabel("Time Window")
plt.ylabel("Zone")
format_axis_ticks(ax, decimals=0)   # round to integers
plt.show()

# 3. Day of Week × Time Window
pivot_day_time_entries = mae_by_day_time.pivot(index="datetime_day_week", columns="datetime_W", values="y_true_entries_score")
pivot_day_time_exits   = mae_by_day_time.pivot(index="datetime_day_week", columns="datetime_W", values="y_true_exits_score")


plt.figure(figsize=(8, 6))
ax = sns.heatmap(pivot_day_time_entries, cmap="YlGnBu", annot=False, cbar_kws={'label': 'MAE'})
plt.title("Entries MAE by Day × Time Window")
plt.xlabel("Time Window")
plt.ylabel("Day of Week")
ax.set_xticks(range(0, len(pivot_day_time_entries.columns), 4))  # show every 4th time window (adjust as needed)
ax.set_xticklabels(pivot_day_time_entries.columns[::4].astype(int), rotation=45)
ax.set_yticks(range(len(pivot_day_time_entries.index)))
ax.set_yticklabels(pivot_day_time_entries.index.astype(int))
plt.tight_layout()
plt.show()

plt.figure(figsize=(8, 6))
ax = sns.heatmap(pivot_day_time_exits, cmap="YlOrRd", annot=False, cbar_kws={'label': 'MAE'})
plt.title("Exits MAE by Day × Time Window")
plt.xlabel("Time Window")
plt.ylabel("Day of Week")
ax.set_xticks(range(0, len(pivot_day_time_exits.columns), 4))  # show every 4th time window (adjust as needed)
ax.set_xticklabels(pivot_day_time_exits.columns[::4].astype(int), rotation=45)
ax.set_yticks(range(len(pivot_day_time_exits.index)))
ax.set_yticklabels(pivot_day_time_exits.index.astype(int))
plt.tight_layout()
plt.show()

# %% [markdown]
# Multidimensionality

# %%
# Compute mean MAE across subgroups in each dimension
avg_day = mae_by_day_week[['y_true_entries_score', 'y_true_exits_score']].mean()
avg_time = mae_by_datetime_W[['y_true_entries_score', 'y_true_exits_score']].mean()
avg_zone = mae_by_zone_codes[['y_true_entries_score', 'y_true_exits_score']].mean()

avg_mae_summary = pd.DataFrame({
    'Dimension': ['Day of Week', 'Datetime Winddow', 'Zone'],
    'Avg Entry MAE': [avg_day['y_true_entries_score'], avg_time['y_true_entries_score'], avg_zone['y_true_entries_score']],
    'Avg Exit MAE': [avg_day['y_true_exits_score'], avg_time['y_true_exits_score'], avg_zone['y_true_exits_score']]
})
avg_mae_summary.head(10)
# Out:
#           Dimension  Avg Entry MAE  Avg Exit MAE
# 0       Day of Week       5.296962      4.728614
# 1  Datetime Winddow       4.702660      4.207081
# 2              Zone       4.801512      4.303432
